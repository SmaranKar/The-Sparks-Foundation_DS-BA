# %% [markdown]
# # The Sparks Foundation - Prediction using Decision Tree Algorithm

# %% [markdown]
# ## Task: To Create the Decision Tree classifier and visualize it graphically.

# %% [markdown]
# ### Step-1 Importing libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn.datasets as datasets
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn import tree
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report,accuracy_score
# %matplotlib inline

# %% [markdown]
# ### Step-2 Loading the dataset

# %%
iris=pd.read_csv("Iris.csv")
print("Dataset loaded successfully")
# Out:
# Dataset loaded successfully

# %% [markdown]
# ### Step-3 Exploratory Data Analysis

# %% [markdown]
# #### Reading Dataset

# %%
#Top values of dataset
iris.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
#Bottom values of dataset
iris.tail()
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 145  Iris-virginica
# 146  Iris-virginica
# 147  Iris-virginica
# 148  Iris-virginica
# 149  Iris-virginica

# %% [markdown]
# ### Step-4 Shape of Data

# %%
iris.shape
# Out:
# (150, 6)

# %%
iris.columns
# Out:
# Index(['Id', 'SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm',
#        'Species'],
#       dtype='object')

# %%
iris["Species"].value_counts()
# Out:
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: Species, dtype: int64

# %%
#Droping the ID column as it is not required.
iris = iris.drop('Id', axis=1)

# %% [markdown]
# ### Step-5 Data Information

# %%
iris.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   SepalLengthCm  150 non-null    float64
#  1   SepalWidthCm   150 non-null    float64
#  2   PetalLengthCm  150 non-null    float64
#  3   PetalWidthCm   150 non-null    float64
#  4   Species        150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %% [markdown]
# ### Step-6 Statistical Properties of Dataset

# %%
iris.describe()
# Out:
#        SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count     150.000000    150.000000     150.000000    150.000000
# mean        5.843333      3.054000       3.758667      1.198667
# std         0.828066      0.433594       1.764420      0.763161
# min         4.300000      2.000000       1.000000      0.100000
# 25%         5.100000      2.800000       1.600000      0.300000
# 50%         5.800000      3.000000       4.350000      1.300000
# 75%         6.400000      3.300000       5.100000      1.800000
# max         7.900000      4.400000       6.900000      2.500000

# %%
iris.isnull().sum()
# Out:
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %% [markdown]
# ### Step-7 Input data visualization

# %%
sns.pairplot(iris, hue='Species')

# %% [markdown]
# ### Step-8 Correlation function

# %%
print(iris.corr())
sns.heatmap(iris.corr(), annot = True)
# Out:
#                SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# SepalLengthCm       1.000000     -0.109369       0.871754      0.817954
# SepalWidthCm       -0.109369      1.000000      -0.420516     -0.356544
# PetalLengthCm       0.871754     -0.420516       1.000000      0.962757
# PetalWidthCm        0.817954     -0.356544       0.962757      1.000000
# C:\Users\smara\AppData\Local\Temp\ipykernel_13512\2411891385.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   print(iris.corr())
# C:\Users\smara\AppData\Local\Temp\ipykernel_13512\2411891385.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
# ...

# %% [markdown]
# We observed that: (i)Petal length is highly related to petal width (ii)Sepal length is not related to sepal width

# %% [markdown]
# ### Step-9 Data Prepration

# %%
x=iris.drop('Species',axis=1)
y=iris.Species

# %% [markdown]
# ### Step-10 Split dataset into train and test sets

# %%
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)
print("Training split:",X_train.shape)
print("Testing spllit:",X_test.shape)
# Out:
# Training split: (120, 4)
# Testing spllit: (30, 4)

# %% [markdown]
# ### Step-11 Defining the Decision Tree Algorithm

# %%
dtc = DecisionTreeClassifier()
clf = dtc.fit(X_train,y_train)
print('Decision Tree Classifer Created Successfully')
# Out:
# Decision Tree Classifer Created Successfully

# %%
y_predict = dtc.predict(X_test)

# %% [markdown]
# #### Predicting with new values

# %%
clf.predict([['3.0','2.5','2.4','0.2']])
# Out:
# C:\Users\smara\anaconda3\lib\site-packages\sklearn\base.py:420: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# array(['Iris-setosa'], dtype=object)

# %% [markdown]
# ### Step-12 Accuracy of the model

# %%
print("Accuracy:",accuracy_score(y_test,y_predict))
# Out:
# Accuracy: 1.0

# %% [markdown]
# ### Step-13 Classification Report and Confusion Matrix

# %%
confusion_matrix(y_test, y_predict)
sns.heatmap(confusion_matrix(y_test, y_predict),annot = True)
# Out:
# <Axes: >

# %%
print(classification_report(y_test, y_predict))
# Out:
#                  precision    recall  f1-score   support
#
#     Iris-setosa       1.00      1.00      1.00        10
# Iris-versicolor       1.00      1.00      1.00         9
#  Iris-virginica       1.00      1.00      1.00        11
#
#        accuracy                           1.00        30
#       macro avg       1.00      1.00      1.00        30
#    weighted avg       1.00      1.00      1.00        30

# %% [markdown]
# ### Step-14 Visualizing the Decision tree

# %%
plt.figure(figsize=(20,10))
tree=tree.plot_tree(dtc,feature_names=iris.columns,precision=2,rounded=True,filled=True,class_names=y.values)

# %% [markdown]
# ### Thank You
